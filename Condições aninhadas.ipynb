# %%
ano=int(input("Qual seu ano de nascimento? "))
if ano==18:
  print("Hora de se alistar")
elif ano<18:
  f=18-ano
  print(f"ainda não é hora de se alistar. Faltam {f} anos")
else:
  p=ano-18
  print(f"passou da hora de se alistar. Você tem {p} anos a mais")
# Out:
# Qual seu ano de nascimento? 2
# ainda não é hora de se alistar. Faltam 16 anos

# %%
m=float(input("Qual foi sua media? "))
if m>=7:
  print("APROVADO")
elif m<5:
  print("REPROVADO")
elif m>=5 and m<=6.9:
  print("RECUPERAÇÃO")
# Out:
# Qual foi sua media? 6
# RECUPERAÇÃO

# %%
i=int(input("Qual a sua idade? "))
if i<=9:
  print("mirim")
elif i<=14:
  print("infantil")
elif i<=19:
  print("junior")
elif i<=25:
  print("senior")
else:
  print("master")
# Out:
# Qual a sua idade? 300
# master

# %%
import math
a1=float(input("Qual o angulo? "))
a2=float(input("Qual o angulo? "))
a3=float(input("Qual o angulo? "))
#para ser um triangulo:
e = a3!=0 and a1!=0 and a2!=0
e = (a1+a2)>a3
e = (a1+a3)>a2
e = (a3+a2)>a1
e = math.fabs(a3-a2)<a1 or math.fabs(a1-a2)<a3 or math.fabs(a3-a1)<a2
if e==True:
    if a1==a2==a3:
      t="equilátero"
    elif a1!=a3 and a2!=a3 and a2!=a1:
      t="escaleno"
    else:
      t="isósceles"

    print(f"é um triângulo {t}")

else:
    print("não é um triangulo")
# Out:
# Qual o angulo? 2
# Qual o angulo? 2
# Qual o angulo? 3
# é um triângulo isósceles

# %%
p=float(input("peso em kg: "))
a=float(input("altura em metros: "))
imc=p/a**2
if imc<18.5:
  print("abaixo do peso")
elif imc>=18.5 and imc<25:
  print("peso ideal")
  if imc>=25 and imc<30:
    print("sobrepeso")
elif imc>=30 and imc<40:
  print("obesidade")
else:
  print("obesidade mórbida")
# Out:
# peso em kg: 55
# altura em metros: 1.5
# peso ideal

# %%
p=float(input("Preço do produto: "))
print("OPÇÕES DE PAGAMENTO")
print("à vista dinheiro/cheque--10% de desconto--digite: 1")
print("à vista no cartão--5% de desconto--digite: 2")
print("em até 2x no cartão--preço formal--digite: 3")
print("3x ou mais no cartão--20% de juros--digite: 4")
f=str(input("Forma de pagamento: "))

if f=="1":
  a=p-p*0.1
  print(f"Total a pagar: {a}")
elif f=="2":
  a=p-p*0.05
  print(f"Total a pagar: {a}")
elif f=="3":
  a=a/2
  print(f"Total a pagar: Até duas vezes {a}")
elif f=="4":
  q=int(input("quantas vezes? "))
  j=p*0.2
  a=p/q
  print(f"Total a pagar: {a+j/q}")
# Out:
# Preço do produto: 100
# OPÇÕES DE PAGAMENTO
# à vista dinheiro/cheque--10% de desconto--digite: 1
# à vista no cartão--5% de desconto--digite: 2
# em até 2x no cartão--preço formal--digite: 3
# 3x ou mais no cartão--20% de juros--digite: 4
# Forma de pagamento: 4
# quantas vezes? 3
# Total a pagar: 40.0

# %%
p1=str(input("pedra papel ou tesoura? Player 1:  "))
p2=str(input("pedra papel ou tesoura? Player 2:  "))
if p1=="pedra" and p2=="tesoura" or p1=="papel" and p2=="pedra" or p1=="tesoura" and p2=="papel":
  print("Player 1 ganhou")
elif p1==p2:
  print("Empate")
else:
  print("Player 2 ganhou")
# Out:
# pedra papel ou tesoura? Player 1:  tesoura
# pedra papel ou tesoura? Player 2:  pedra
# Player 2 ganhou
